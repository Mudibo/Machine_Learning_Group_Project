# %% [markdown]
# # Sprint 2 - Feature Engineering
#
# TODO: Document engineered features and why they are expected to improve performance.

# %%
# TODO: Build and inspect feature set
import pandas as pd

# TODO: Replace with feature engineering implementation
feature_df = pd.DataFrame()
feature_df.head()
