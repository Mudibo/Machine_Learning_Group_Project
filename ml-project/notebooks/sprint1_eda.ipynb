# %% [markdown]
# # Sprint 1 - Exploratory Data Analysis (EDA)
#
# TODO: Document dataset overview, key questions, and expected insights.

# %%
# TODO: Import libraries and load raw dataset for EDA
import pandas as pd

# TODO: Replace with actual dataset path
df = pd.DataFrame()
df.head()
