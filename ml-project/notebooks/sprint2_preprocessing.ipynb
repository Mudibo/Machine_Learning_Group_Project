# %% [markdown]
# # Sprint 2 - Data Preprocessing
#
# TODO: Describe preprocessing assumptions, transformations, and validation checks.

# %%
# TODO: Load cleaned data and apply preprocessing steps
import pandas as pd

# TODO: Replace with preprocessing implementation
processed_df = pd.DataFrame()
processed_df.head()
