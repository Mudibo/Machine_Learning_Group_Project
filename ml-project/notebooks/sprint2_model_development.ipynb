# %% [markdown]
# # Sprint 2 - Model Development
#
# TODO: Track baseline model, tuned models, and experiment outcomes.

# %%
# TODO: Train baseline model and compare alternatives
from sklearn.dummy import DummyClassifier

# TODO: Replace with real training pipeline
model = DummyClassifier(strategy="most_frequent")
model
