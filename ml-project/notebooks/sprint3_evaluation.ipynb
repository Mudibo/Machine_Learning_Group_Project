# %% [markdown]
# # Sprint 3 - Model Evaluation
#
# TODO: Define evaluation protocol, metrics, and interpretation criteria.

# %%
# TODO: Evaluate trained model on validation/test data
from sklearn.metrics import accuracy_score

# TODO: Replace placeholders with actual predictions
y_true, y_pred = [0], [0]
accuracy_score(y_true, y_pred)
