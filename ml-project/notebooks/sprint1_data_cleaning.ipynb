# %% [markdown]
# # Sprint 1 - Data Cleaning
#
# TODO: Track data quality issues and cleaning strategy decisions.

# %%
# TODO: Load raw data and implement cleaning pipeline
import pandas as pd

# TODO: Replace with cleaning logic
clean_df = pd.DataFrame()
clean_df.info()
